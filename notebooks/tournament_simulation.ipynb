# %%
import pandas as pd
import joblib
import numpy as np
from collections import Counter

# %%
df = pd.read_csv('/content/team_features.csv')
df.head()
# Out:
#          date         team     opponent  team_score  opponent_score  win  \
# 0  2010-01-02         Iran  North Korea         1.0             0.0    1
# 1  2010-01-02         Mali        Qatar         0.0             0.0    0
# 2  2010-01-02  North Korea         Iran         0.0             1.0    0
# 3  2010-01-02        Qatar         Mali         0.0             0.0    0
# 4  2010-01-02        Syria     Zimbabwe         6.0             0.0    1
#
#    neutral  avg_goals_last_5  win_rate_last_5  avg_goals_conceded_last_5  \
# 0     True               NaN              NaN                        NaN
# 1    False               NaN              NaN                        NaN
# 2     True               NaN              NaN                        NaN
# 3    False               NaN              NaN                        NaN
# 4     True               NaN              NaN                        NaN
#
#    goal_diff  avg_goal_diff_last_5  days_since_last_match
# 0        1.0                   NaN                    NaN
# 1        0.0                   NaN                    NaN
# 2       -1.0                   NaN                    NaN
# 3        0.0                   NaN                    NaN
# 4        6.0                   NaN                    NaN

# %%
latest_features = df.sort_values(by="date").groupby("team").tail(1).set_index("team")
latest_features
# Out:
#                                  date       opponent  team_score  \
# team
# Rhodes                     2011-06-27         Jersey         0.0
# Kiribati                   2011-09-05         Tahiti         1.0
# Cilento                    2011-12-29      Occitania         0.0
# Western Sahara             2012-06-09      Occitania         1.0
# Saint Pierre and Miquelon  2012-09-28  New Caledonia         1.0
# ...                               ...            ...         ...
# Dominican Republic         2025-11-18     Martinique         0.0
# Hong Kong                  2025-11-18      Singapore         1.0
# Zambia                     2025-11-18         Angola         2.0
# Laos                       2025-11-19        Vietnam         0.0
# Vietnam                    2025-11-19           Laos         2.0
#
#                            opponent_score  win  neutral  avg_goals_last_5  \
# team
# Rhodes                                2.0    0     True          2.000000
# Kiribati                             17.0    0     True          0.333333
# Cilento                               2.0    0    False               NaN
# Western Sahara                        3.0    0     True          2.500000
# Saint Pierre and Miquelon            16.0    0     True          0.200000
# ...                                   ...  ...      ...               ...
# Dominican Republic                    0.0    0    False          0.600000
# Hong Kong                             2.0    0    False          3.000000
# Zambia                                3.0    0    False          0.400000
# Laos                                  2.0    0    False          0.800000
# Vietnam                               0.0    1    False          2.200000
#
#                            win_rate_last_5  avg_goals_conceded_last_5  \
# team
# Rhodes                                 1.0                   1.000000
# Kiribati                               0.0                   9.666667
# Cilento                                NaN                        NaN
# Western Sahara                         0.5                   3.250000
# Saint Pierre and Miquelon              0.0                  10.200000
# ...                                    ...                        ...
# Dominican Republic                     0.2                   1.200000
# Hong Kong                              0.4                   1.400000
# Zambia                                 0.2                   2.200000
# Laos                                   0.2                   3.200000
# Vietnam                                0.8                   1.200000
#
#                            goal_diff  avg_goal_diff_last_5  \
# team
# Rhodes                          -2.0              1.000000
# Kiribati                       -16.0             -9.333333
# Cilento                         -2.0                   NaN
# Western Sahara                  -2.0             -0.750000
# Saint Pierre and Miquelon      -15.0            -10.000000
# ...                              ...                   ...
# Dominican Republic               0.0             -0.600000
# Hong Kong                       -1.0              1.600000
# Zambia                          -1.0             -1.800000
# Laos                            -2.0             -2.400000
# Vietnam                          2.0              1.000000
#
#                            days_since_last_match
# team
# Rhodes                                       1.0
# Kiribati                                     2.0
# Cilento                                      NaN
# Western Sahara                               1.0
# Saint Pierre and Miquelon                    2.0
# ...                                          ...
# Dominican Republic                           6.0
# Hong Kong                                    5.0
# Zambia                                       3.0
# Laos                                        36.0
# Vietnam                                     36.0
#
# [309 rows x 12 columns]

# %%
FEATURES = ["avg_goals_last_5", "win_rate_last_5", "neutral", "avg_goals_conceded_last_5", "avg_goal_diff_last_5"]

latest_features = latest_features.dropna(subset=FEATURES + ["win"]).copy()

# %%
model = joblib.load('soccer_model.pkl')
scaler = joblib.load('soccer_scaler.pkl')

# %%
teams = latest_features.index.tolist()  # all teams in simulation
teams
# Out:
# ['Rhodes',
#  'Kiribati',
#  'Western Sahara',
#  'Saint Pierre and Miquelon',
#  'Provence',
#  'Brittany',
#  'Darfur',
#  'Arameans Suryoye',
#  'Sealand',
#  'Occitania',
#  'County of Nice',
#  'Romani people',
#  'Galicia',
#  'Iraqi Kurdistan',
#  'Délvidék',
#  'Monaco',
#  'Corsica',
#  'Felvidék',
#  'Saare County',
#  'Gotland',
#  'Donetsk PR',
#  'Ellan Vannin',
#  'United Koreans in Japan',
#  'Northern Cyprus',
#  'Kabylia',
#  'Kárpátalja',
#  'Vatican City',
#  'Catalonia',
#  'Somaliland',
#  'Cascadia',
#  'Barawa',
#  'Yorkshire',
#  'Parishes of Jersey',
#  'Padania',
#  'Abkhazia',
#  'Artsakh',
#  'Western Armenia',
#  'Franconia',
#  'Eritrea',
#  'Luhansk PR',
#  'South Ossetia',
#  'Chagos Islands',
#  'Panjab',
#  'Basque Country',
#  'Alderney',
#  'Yoruba Nation',
#  'Biafra',
#  'Matabeleland',
#  'Mapuche',
#  'Maule Sur',
#  'Aymara',
#  'Saint Barthélemy',
#  'Chameria',
#  'Székely Land',
#  'Two Sicilies',
#  'Saint Helena',
#  'Menorca',
#  'Åland Islands',
#  'Guernsey',
#  'Greenland',
#  'Falkland Islands',
#  'Isle of Wight',
#  'Kernow',
#  'Sápmi',
#  'Raetia',
#  'Tibet',
#  'Ticino',
#  'Hmong',
#  'Tamil Eelam',
#  'Mayotte',
#  'Réunion',
#  'Tuvalu',
#  'Northern Mariana Islands',
#  'American Samoa',
#  'Cook Islands',
#  'Tonga',
#  'Montserrat',
#  'Samoa',
#  'French Guiana',
#  'Mongolia',
#  'Guam',
#  'Solomon Islands',
#  'Papua New Guinea',
#  'Zanzibar',
#  'Macau',
#  'Tahiti',
#  'Bermuda',
#  'Nicaragua',
#  'North Korea',
#  'China PR',
#  'Kyrgyzstan',
#  'Suriname',
#  'Trinidad and Tobago',
#  'Haiti',
#  'Curaçao',
#  'El Salvador',
#  'Guadeloupe',
#  'Jamaica',
#  'Panama',
#  'Costa Rica',
#  'Guatemala',
#  'Honduras',
#  'Ynys Môn',
#  'Shetland',
#  'Orkney',
#  'Western Isles',
#  'Hitra',
#  'Gozo',
#  'Frøya',
#  'Isle of Man',
#  'Jersey',
#  'United States Virgin Islands',
#  'Turks and Caicos Islands',
#  'Marshall Islands',
#  'Palestine',
#  'New Caledonia',
#  'Indonesia',
#  'Grenada',
#  'Guinea-Bissau',
#  'Sierra Leone',
#  'Central African Republic',
#  'Djibouti',
#  'Ethiopia',
#  'South Sudan',
#  'São Tomé and Príncipe',
#  'Togo',
#  'Mauritius',
#  'Eswatini',
#  'Rwanda',
#  'Puerto Rico',
#  'Myanmar',
#  'Seychelles',
#  'Congo',
#  'Burundi',
#  'Botswana',
#  'Afghanistan',
#  'Cambodia',
#  'Cameroon',
#  'Gabon',
#  'Sudan',
#  'Argentina',
#  'Saint Martin',
#  'Saint Lucia',
#  'Russia',
#  'Mauritania',
#  'Saint Vincent and the Grenadines',
#  'Sint Maarten',
#  'South Africa',
#  'Tanzania',
#  'Libya',
#  'Liberia',
#  'Bahamas',
#  'Anguilla',
#  'Aruba',
#  'Barbados',
#  'Bonaire',
#  'British Virgin Islands',
#  'Cayman Islands',
#  'Dominica',
#  'Cuba',
#  'Latvia',
#  'Serbia',
#  'Republic of Ireland',
#  'Portugal',
#  'Norway',
#  'Ukraine',
#  'Moldova',
#  'Italy',
#  'Nigeria',
#  'Iceland',
#  'Hungary',
#  'France',
#  'England',
#  'DR Congo',
#  'Azerbaijan',
#  'Armenia',
#  'Albania',
#  'Israel',
#  'Malta',
#  'Montenegro',
#  'Mozambique',
#  'Netherlands',
#  'Northern Ireland',
#  'Vanuatu',
#  'Qatar',
#  'Slovakia',
#  'Somalia',
#  'Madagascar',
#  'Zimbabwe',
#  'Poland',
#  'Luxembourg',
#  'Namibia',
#  'Gibraltar',
#  'Lithuania',
#  'Andorra',
#  'Bahrain',
#  'Chad',
#  'Comoros',
#  'Croatia',
#  'Cape Verde',
#  'Egypt',
#  'Equatorial Guinea',
#  'Fiji',
#  'Finland',
#  'Germany',
#  'Czech Republic',
#  'Saudi Arabia',
#  'Paraguay',
#  'San Marino',
#  'Saint Kitts and Nevis',
#  'Romania',
#  'Malaysia',
#  'Philippines',
#  'Peru',
#  'Pakistan',
#  'Mexico',
#  'North Macedonia',
#  'Niger',
#  'New Zealand',
#  'Nepal',
#  'Morocco',
#  'Martinique',
#  'Mali',
#  'Maldives',
#  'Scotland',
#  'Oman',
#  'Senegal',
#  'United States',
#  'Slovenia',
#  'Wales',
#  'Venezuela',
#  'Uzbekistan',
#  'Uruguay',
#  'Malawi',
#  'United Arab Emirates',
#  'Uganda',
#  'Turkmenistan',
#  'Turkey',
#  'Singapore',
#  'Tunisia',
#  'Thailand',
#  'Tajikistan',
#  'Taiwan',
#  'Syria',
#  'Switzerland',
#  'Sweden',
#  'Sri Lanka',
#  'Spain',
#  'South Korea',
#  'Timor-Leste',
#  'Liechtenstein',
#  'Georgia',
#  'Lebanon',
#  'Canada',
#  'Burkina Faso',
#  'Bulgaria',
#  'Brunei',
#  'Brazil',
#  'Bosnia and Herzegovina',
#  'Bolivia',
#  'Bhutan',
#  'Benin',
#  'Belize',
#  'Belgium',
#  'Belarus',
#  'Bangladesh',
#  'Austria',
#  'Australia',
#  'Antigua and Barbuda',
#  'Angola',
#  'Algeria',
#  'Yemen',
#  'Chile',
#  'Colombia',
#  'Cyprus',
#  'Denmark',
#  'Kuwait',
#  'Kosovo',
#  'Kenya',
#  'Kazakhstan',
#  'Jordan',
#  'Japan',
#  'Ivory Coast',
#  'Iraq',
#  'Iran',
#  'Lesotho',
#  'India',
#  'Guyana',
#  'Guinea',
#  'Greece',
#  'Ghana',
#  'Gambia',
#  'Faroe Islands',
#  'Estonia',
#  'Ecuador',
#  'Dominican Republic',
#  'Hong Kong',
#  'Zambia',
#  'Laos',
#  'Vietnam']

# %%
def simulate_match(team_a, team_b, team_table, model):
  row_a = team_table.loc[team_a]
  row_b = team_table.loc[team_b]

  feature_values = {
    "avg_goals_last_5": row_a["avg_goals_last_5"] - row_b["avg_goals_last_5"],
    "win_rate_last_5": row_a["win_rate_last_5"] - row_b["win_rate_last_5"],
    "neutral": 1, # Neutral is a constant feature and should be handled accordingly
    "avg_goals_conceded_last_5": row_a["avg_goals_conceded_last_5"] - row_b["avg_goals_conceded_last_5"],
    "avg_goal_diff_last_5": row_a["avg_goal_diff_last_5"] - row_b["avg_goal_diff_last_5"]
  }

  # Ensure the feature_diff DataFrame has columns in the same order as FEATURES
  # FEATURES list is defined as: ['avg_goals_last_5', 'win_rate_last_5', 'neutral', 'avg_goals_conceded_last_5', 'avg_goal_diff_last_5']
  feature_diff = pd.DataFrame([feature_values], columns=FEATURES)

  win_prob = model.predict_proba(feature_diff)[0, 1]
  winner = team_a if np.random.rand() < win_prob else team_b
  print(f"{'MATCHUP':<35} | {'WINNER':<15} | {'WIN PROB'}")
  print("-" * 65)

  # Example of how to print inside your loop
  # Assuming you have: team_a, team_b, winner, win_prob
  match_str = f"{team_a} vs {team_b}"
  print(f"{match_str:<35} | {winner:<15} | {win_prob:.2%}")
  return winner

# %%
def simulate_round(teams, team_table, model):
    """
    Simulate one knockout round.
    teams: list of team names
    Returns list of winners
    """
    np.random.shuffle(teams)
    winners = []

    for i in range(0, len(teams), 2):
        team_a = teams[i]
        team_b = teams[i+1]
        winner = simulate_match(team_a, team_b, team_table, model)
        winners.append(winner)

    return winners

# %%
def simulate_tournament(teams, team_table, model):
    round_teams = teams.copy()
    while len(round_teams) > 1:
        print("\n" + "="*40)
        print(f"Knockout ROUND")
        print("="*40)
        round_teams = simulate_round(round_teams, team_table, model)
    return round_teams[0]  # champion

# %%
world_cup_teams = [
    "Spain", "Argentina", "France", "England",
    "Brazil", "Portugal", "Netherlands", "Belgium",
    "Germany", "Croatia", "Morocco", "Italy",
    "Colombia", "United States", "Mexico", "Uruguay"
]
worldcup_winner = simulate_tournament(world_cup_teams, latest_features, model)

print("\n" + "="*40)
print(f"🏆 THE WINNER OF THE 2026 WORLD CUP IS: {worldcup_winner.upper()} 🏆")
print("="*40)
# Out:
# ========================================
# Knockout ROUND
# ========================================
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Germany vs Argentina                | Argentina       | 35.15%
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Italy vs Belgium                    | Belgium         | 36.18%
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Mexico vs Uruguay                   | Uruguay         | 26.70%
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Spain vs Portugal                   | Spain           | 55.31%
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# United States vs England            | England         | 21.74%
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Brazil vs France                    | France          | 34.90%
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Netherlands vs Morocco              | Morocco         | 35.27%
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Colombia vs Croatia                 | Croatia         | 37.94%
#
# ========================================
# Knockout ROUND
# ========================================
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Uruguay vs Belgium                  | Uruguay         | 28.39%
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# France vs England                   | England         | 29.36%
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Spain vs Argentina                  | Spain           | 49.73%
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Croatia vs Morocco                  | Morocco         | 37.09%
#
# ========================================
# Knockout ROUND
# ========================================
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# England vs Morocco                  | England         | 45.47%
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Spain vs Uruguay                    | Spain           | 54.26%
#
# ========================================
# Knockout ROUND
# ========================================
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Spain vs England                    | Spain           | 39.67%
#
# ========================================
# 🏆 THE WINNER OF THE 2026 WORLD CUP IS: SPAIN 🏆
# ========================================

# %%
world_cup_teams = [
    "Spain", "Argentina", "France", "England",
    "Brazil", "Portugal", "Netherlands", "Belgium",
    "Germany", "Croatia", "Morocco", "Italy",
    "Colombia", "United States", "Mexico", "Uruguay"
]
winners_list = []

for i in range(10000):
    worldcup_winner = simulate_tournament(world_cup_teams, latest_features, model)
    winners_list.append(worldcup_winner)
# Out:
# Streaming output truncated to the last 5000 lines.
# Knockout ROUND
# ========================================
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Colombia vs Brazil                  | Colombia        | 40.95%
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# England vs France                   | France          | 46.24%
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Belgium vs Italy                    | Belgium         | 38.67%
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Uruguay vs Portugal                 | Portugal        | 38.42%
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Croatia vs Argentina                | Argentina       | 38.87%
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Morocco vs Germany                  | Morocco         | 41.56%
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Spain vs Mexico                     | Spain           | 66.07%
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# United States vs Netherlands        | United States   | 29.83%
#
# ========================================
# Knockout ROUND
# ========================================
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# United States vs France             | United States   | 28.55%
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Portugal vs Belgium                 | Belgium         | 27.54%
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Argentina vs Morocco                | Argentina       | 35.66%
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Spain vs Colombia                   | Spain           | 47.64%
#
# ========================================
# Knockout ROUND
# ========================================
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# United States vs Argentina          | Argentina       | 29.47%
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Belgium vs Spain                    | Spain           | 31.25%
#
# ========================================
# Knockout ROUND
# ========================================
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Argentina vs Spain                  | Argentina       | 26.55%
#
# ========================================
# Knockout ROUND
# ========================================
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Uruguay vs Brazil                   | Brazil          | 34.72%
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Argentina vs Belgium                | Belgium         | 32.22%
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Croatia vs Portugal                 | Croatia         | 44.31%
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# United States vs Colombia           | Colombia        | 27.76%
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Germany vs Italy                    | Italy           | 31.26%
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# France vs Netherlands               | Netherlands     | 38.87%
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Mexico vs Spain                     | Spain           | 15.51%
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Morocco vs England                  | England         | 30.01%
#
# ========================================
# Knockout ROUND
# ========================================
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Colombia vs England                 | England         | 30.17%
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Brazil vs Belgium                   | Belgium         | 30.83%
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Croatia vs Netherlands              | Netherlands     | 39.28%
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Spain vs Italy                      | Italy           | 45.35%
#
# ========================================
# Knockout ROUND
# ========================================
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# England vs Netherlands              | Netherlands     | 47.78%
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Belgium vs Italy                    | Italy           | 38.67%
#
# ========================================
# Knockout ROUND
# ========================================
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Italy vs Netherlands                | Netherlands     | 42.03%
#
# ========================================
# Knockout ROUND
# ========================================
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Mexico vs Portugal                  | Portugal        | 27.54%
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# France vs Germany                   | Germany         | 40.81%
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Argentina vs Morocco                | Morocco         | 35.66%
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Colombia vs Brazil                  | Brazil          | 40.95%
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Uruguay vs Italy                    | Italy           | 29.49%
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Belgium vs United States            | United States   | 51.82%
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# England vs Spain                    | Spain           | 35.22%
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Croatia vs Netherlands              | Netherlands     | 39.28%
#
# ========================================
# Knockout ROUND
# ========================================
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Brazil vs United States             | Brazil          | 44.50%
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Netherlands vs Italy                | Netherlands     | 33.02%
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Spain vs Portugal                   | Portugal        | 55.31%
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Germany vs Morocco                  | Morocco         | 33.45%
#
# ========================================
# Knockout ROUND
# ========================================
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Morocco vs Netherlands              | Netherlands     | 39.61%
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Brazil vs Portugal                  | Brazil          | 41.22%
#
# ========================================
# Knockout ROUND
# ========================================
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Netherlands vs Brazil               | Brazil          | 38.54%
#
# ========================================
# Knockout ROUND
# ========================================
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Colombia vs Belgium                 | Belgium         | 34.08%
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# United States vs Croatia            | Croatia         | 28.21%
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Germany vs Spain                    | Spain           | 24.68%
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Italy vs Uruguay                    | Italy           | 46.09%
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# England vs Netherlands              | Netherlands     | 47.78%
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# France vs Morocco                   | Morocco         | 36.69%
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Argentina vs Mexico                 | Mexico          | 54.06%
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Portugal vs Brazil                  | Brazil          | 33.76%
#
# ========================================
# Knockout ROUND
# ========================================
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Italy vs Morocco                    | Morocco         | 39.79%
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Netherlands vs Mexico               | Mexico          | 53.64%
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Brazil vs Belgium                   | Belgium         | 30.83%
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Croatia vs Spain                    | Spain           | 27.76%
#
# ========================================
# Knockout ROUND
# ========================================
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Mexico vs Morocco                   | Morocco         | 21.97%
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Spain vs Belgium                    | Spain           | 44.03%
#
# ========================================
# Knockout ROUND
# ========================================
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Morocco vs Spain                    | Morocco         | 28.05%
#
# ========================================
# Knockout ROUND
# ========================================
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Argentina vs Italy                  | Italy           | 33.40%
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Brazil vs Mexico                    | Mexico          | 52.46%
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Germany vs Colombia                 | Germany         | 33.27%
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Spain vs Croatia                    | Croatia         | 48.19%
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# France vs Morocco                   | Morocco         | 36.69%
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# United States vs Portugal           | Portugal        | 34.33%
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# England vs Uruguay                  | England         | 51.89%
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Netherlands vs Belgium              | Belgium         | 31.85%
#
# ========================================
# Knockout ROUND
# ========================================
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Croatia vs England                  | Croatia         | 29.71%
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Belgium vs Portugal                 | Portugal        | 48.47%
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Mexico vs Morocco                   | Morocco         | 21.97%
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Germany vs Italy                    | Germany         | 31.26%
#
# ========================================
# Knockout ROUND
# ========================================
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Portugal vs Croatia                 | Portugal        | 31.00%
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Morocco vs Germany                  | Germany         | 41.56%
#
# ========================================
# Knockout ROUND
# ========================================
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Portugal vs Germany                 | Portugal        | 34.51%
#
# ========================================
# Knockout ROUND
# ========================================
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# United States vs Mexico             | Mexico          | 45.13%
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Netherlands vs Argentina            | Argentina       | 37.02%
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Italy vs Germany                    | Italy           | 44.01%
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Croatia vs Morocco                  | Morocco         | 37.09%
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Portugal vs Spain                   | Spain           | 22.41%
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Colombia vs France                  | Colombia        | 38.34%
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Uruguay vs Brazil                   | Brazil          | 34.72%
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Belgium vs England                  | England         | 33.32%
#
# ========================================
# Knockout ROUND
# ========================================
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Brazil vs Mexico                    | Mexico          | 52.46%
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Spain vs Argentina                  | Spain           | 49.73%
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# England vs Italy                    | Italy           | 43.00%
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Morocco vs Colombia                 | Colombia        | 37.23%
#
# ========================================
# Knockout ROUND
# ========================================
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Italy vs Spain                      | Spain           | 30.11%
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Mexico vs Colombia                  | Colombia        | 21.84%
#
# ========================================
# Knockout ROUND
# ========================================
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Colombia vs Spain                   | Colombia        | 28.21%
#
# ========================================
# Knockout ROUND
# ========================================
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# United States vs Belgium            | Belgium         | 24.94%
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Argentina vs Netherlands            | Argentina       | 37.82%
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Italy vs Uruguay                    | Italy           | 46.09%
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Colombia vs Spain                   | Spain           | 28.21%
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Morocco vs England                  | England         | 30.01%
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Germany vs Brazil                   | Germany         | 36.64%
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# France vs Mexico                    | France          | 55.17%
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Croatia vs Portugal                 | Portugal        | 44.31%
#
# ========================================
# Knockout ROUND
# ========================================
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Portugal vs France                  | France          | 31.37%
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Germany vs Argentina                | Argentina       | 35.15%
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Spain vs England                    | England         | 39.67%
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Italy vs Belgium                    | Italy           | 36.18%
#
# ========================================
# Knockout ROUND
# ========================================
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Argentina vs France                 | France          | 36.38%
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Italy vs England                    | England         | 32.15%
#
# ========================================
# Knockout ROUND
# ========================================
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# France vs England                   | England         | 29.36%
#
# ========================================
# Knockout ROUND
# ========================================
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Colombia vs Portugal                | Colombia        | 44.85%
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Argentina vs United States          | United States   | 46.10%
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Brazil vs Croatia                   | Croatia         | 34.51%
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Spain vs Italy                      | Spain           | 45.35%
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Mexico vs Morocco                   | Morocco         | 21.97%
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# England vs Netherlands              | Netherlands     | 47.78%
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Germany vs France                   | France          | 34.14%
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Belgium vs Uruguay                  | Belgium         | 47.41%
#
# ========================================
# Knockout ROUND
# ========================================
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Colombia vs France                  | France          | 38.34%
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Belgium vs United States            | United States   | 51.82%
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Morocco vs Netherlands              | Morocco         | 39.61%
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Croatia vs Spain                    | Spain           | 27.76%
#
# ========================================
# Knockout ROUND
# ========================================
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Spain vs France                     | France          | 48.61%
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Morocco vs United States            | Morocco         | 47.99%
#
# ========================================
# Knockout ROUND
# ========================================
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# France vs Morocco                   | Morocco         | 36.69%
#
# ========================================
# Knockout ROUND
# ========================================
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Germany vs Argentina                | Argentina       | 35.15%
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Portugal vs Colombia                | Colombia        | 30.53%
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Morocco vs France                   | France          | 38.15%
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# United States vs Uruguay            | Uruguay         | 33.38%
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Netherlands vs Belgium              | Belgium         | 31.85%
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Italy vs Spain                      | Italy           | 30.11%
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Croatia vs Brazil                   | Croatia         | 40.42%
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# England vs Mexico                   | England         | 63.90%
#
# ========================================
# Knockout ROUND
# ========================================
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Uruguay vs Colombia                 | Uruguay         | 31.44%
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Argentina vs Belgium                | Belgium         | 32.22%
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# France vs Croatia                   | France          | 37.02%
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Italy vs England                    | England         | 32.15%
#
# ========================================
# Knockout ROUND
# ========================================
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# England vs Uruguay                  | England         | 51.89%
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Belgium vs France                   | Belgium         | 41.83%
#
# ========================================
# Knockout ROUND
# ========================================
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Belgium vs England                  | Belgium         | 33.32%
#
# ========================================
# Knockout ROUND
# ========================================
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Brazil vs Italy                     | Italy           | 31.98%
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Colombia vs Mexico                  | Mexico          | 56.13%
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Croatia vs Portugal                 | Portugal        | 44.31%
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# England vs Spain                    | England         | 35.22%
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# United States vs Argentina          | Argentina       | 29.47%
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Netherlands vs Morocco              | Morocco         | 35.27%
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Belgium vs Germany                  | Germany         | 45.33%
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# France vs Uruguay                   | Uruguay         | 42.85%
#
# ========================================
# Knockout ROUND
# ========================================
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Germany vs Argentina                | Germany         | 35.15%
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# England vs Italy                    | England         | 43.00%
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Morocco vs Mexico                   | Mexico          | 55.94%
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Uruguay vs Portugal                 | Uruguay         | 38.42%
#
# ========================================
# Knockout ROUND
# ========================================
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Mexico vs Germany                   | Germany         | 25.09%
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# England vs Uruguay                  | England         | 51.89%
#
# ========================================
# Knockout ROUND
# ========================================
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# England vs Germany                  | Germany         | 49.80%
#
# ========================================
# Knockout ROUND
# ========================================
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Mexico vs Portugal                  | Portugal        | 27.54%
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Brazil vs Germany                   | Germany         | 38.20%
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Belgium vs United States            | Belgium         | 51.82%
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Uruguay vs Morocco                  | Morocco         | 31.61%
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Italy vs Argentina                  | Argentina       | 41.62%
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Spain vs France                     | Spain           | 48.61%
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# England vs Netherlands              | England         | 47.78%
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Croatia vs Colombia                 | Colombia        | 36.90%
#
# ========================================
# Knockout ROUND
# ========================================
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Morocco vs Argentina                | Morocco         | 39.21%
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# England vs Belgium                  | England         | 41.70%
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Portugal vs Spain                   | Spain           | 22.41%
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Colombia vs Germany                 | Germany         | 41.76%
#
# ========================================
# Knockout ROUND
# ========================================
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Morocco vs England                  | England         | 30.01%
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Germany vs Spain                    | Spain           | 24.68%
#
# ========================================
# Knockout ROUND
# ========================================
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Spain vs England                    | Spain           | 39.67%
#
# ========================================
# Knockout ROUND
# ========================================
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Mexico vs United States             | United States   | 30.29%
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Italy vs Netherlands                | Netherlands     | 42.03%
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Spain vs England                    | England         | 39.67%
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Croatia vs Belgium                  | Croatia         | 33.59%
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Morocco vs Colombia                 | Morocco         | 37.23%
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# France vs Uruguay                   | France          | 42.85%
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Germany vs Portugal                 | Portugal        | 40.42%
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Argentina vs Brazil                 | Argentina       | 38.94%
#
# ========================================
# Knockout ROUND
# ========================================
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Morocco vs Netherlands              | Netherlands     | 39.61%
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Portugal vs England                 | England         | 24.11%
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Argentina vs Croatia                | Croatia         | 35.99%
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# United States vs France             | United States   | 28.55%
#
# ========================================
# Knockout ROUND
# ========================================
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# United States vs Netherlands        | Netherlands     | 29.83%
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# England vs Croatia                  | England         | 45.82%
#
# ========================================
# Knockout ROUND
# ========================================
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# England vs Netherlands              | Netherlands     | 47.78%
#
# ========================================
# Knockout ROUND
# ========================================
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Morocco vs Argentina                | Morocco         | 39.21%
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# France vs Croatia                   | Croatia         | 37.02%
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Belgium vs United States            | Belgium         | 51.82%
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Portugal vs Brazil                  | Portugal        | 33.76%
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Colombia vs Italy                   | Colombia        | 35.29%
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Netherlands vs England              | Netherlands     | 28.10%
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Spain vs Germany                    | Germany         | 52.17%
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Mexico vs Uruguay                   | Uruguay         | 26.70%
#
# ========================================
# Knockout ROUND
# ========================================
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Croatia vs Germany                  | Germany         | 41.22%
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Uruguay vs Morocco                  | Morocco         | 31.61%
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Netherlands vs Portugal             | Netherlands     | 42.38%
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Belgium vs Colombia                 | Belgium         | 40.88%
#
# ========================================
# Knockout ROUND
# ========================================
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Netherlands vs Morocco              | Netherlands     | 35.27%
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Germany vs Belgium                  | Belgium         | 30.12%
#
# ========================================
# Knockout ROUND
# ========================================
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Belgium vs Netherlands              | Netherlands     | 43.33%
#
# ========================================
# Knockout ROUND
# ========================================
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Colombia vs United States           | United States   | 48.19%
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Spain vs England                    | Spain           | 39.67%
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# France vs Brazil                    | Brazil          | 40.01%
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Mexico vs Portugal                  | Mexico          | 27.54%
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Italy vs Argentina                  | Argentina       | 41.62%
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Belgium vs Germany                  | Germany         | 45.33%
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Croatia vs Uruguay                  | Croatia         | 43.26%
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Netherlands vs Morocco              | Netherlands     | 35.27%
#
# ========================================
# Knockout ROUND
# ========================================
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Argentina vs Spain                  | Spain           | 26.55%
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Mexico vs Croatia                   | Mexico          | 22.22%
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Germany vs Brazil                   | Germany         | 36.64%
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# United States vs Netherlands        | United States   | 29.83%
#
# ========================================
# Knockout ROUND
# ========================================
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Mexico vs United States             | United States   | 30.29%
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Germany vs Spain                    | Germany         | 24.68%
#
# ========================================
# Knockout ROUND
# ========================================
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Germany vs United States            | Germany         | 43.68%
#
# ========================================
# Knockout ROUND
# ========================================
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Brazil vs Morocco                   | Brazil          | 34.20%
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Uruguay vs Colombia                 | Colombia        | 31.44%
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Netherlands vs United States        | United States   | 45.68%
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# France vs Argentina                 | France          | 38.47%
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Germany vs Mexico                   | Germany         | 51.62%
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Spain vs Belgium                    | Spain           | 44.03%
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# England vs Portugal                 | England         | 52.95%
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Croatia vs Italy                    | Italy           | 34.78%
#
# ========================================
# Knockout ROUND
# ========================================
# ...
# -----------------------------------------------------------------
# Uruguay vs Morocco                  | Morocco         | 31.61%
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Spain vs Croatia                    | Spain           | 48.19%
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Belgium vs Mexico                   | Mexico          | 59.67%
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Colombia vs France                  | Colombia        | 38.34%
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Netherlands vs United States        | Netherlands     | 45.68%
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Germany vs Brazil                   | Germany         | 36.64%
#
# ========================================
# Knockout ROUND
# ========================================
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Mexico vs Germany                   | Germany         | 25.09%
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# England vs Morocco                  | Morocco         | 45.47%
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Colombia vs Netherlands             | Colombia        | 39.80%
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Argentina vs Spain                  | Spain           | 26.55%
#
# ========================================
# Knockout ROUND
# ========================================
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Germany vs Spain                    | Spain           | 24.68%
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Morocco vs Colombia                 | Morocco         | 37.23%
#
# ========================================
# Knockout ROUND
# ========================================
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Spain vs Morocco                    | Morocco         | 47.84%
#
# ========================================
# Knockout ROUND
# ========================================
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Brazil vs Uruguay                   | Uruguay         | 40.20%
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Belgium vs Argentina                | Argentina       | 42.92%
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Colombia vs Germany                 | Colombia        | 41.76%
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Morocco vs United States            | Morocco         | 47.99%
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Mexico vs France                    | France          | 22.51%
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Portugal vs Netherlands             | Portugal        | 32.71%
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Italy vs England                    | Italy           | 32.15%
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Spain vs Croatia                    | Croatia         | 48.19%
#
# ========================================
# Knockout ROUND
# ========================================
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Italy vs Colombia                   | Colombia        | 39.60%
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Portugal vs Croatia                 | Portugal        | 31.00%
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Morocco vs Argentina                | Argentina       | 39.21%
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Uruguay vs France                   | France          | 32.29%
#
# ========================================
# Knockout ROUND
# ========================================
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Argentina vs Portugal               | Argentina       | 42.79%
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Colombia vs France                  | France          | 38.34%
#
# ========================================
# Knockout ROUND
# ========================================
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# France vs Argentina                 | France          | 38.47%
#
# ========================================
# Knockout ROUND
# ========================================
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Italy vs Argentina                  | Argentina       | 41.62%
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Croatia vs Belgium                  | Belgium         | 33.59%
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# France vs Colombia                  | Colombia        | 36.51%
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Mexico vs Uruguay                   | Mexico          | 26.70%
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# United States vs Brazil             | United States   | 30.83%
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# England vs Netherlands              | England         | 47.78%
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Morocco vs Germany                  | Morocco         | 41.56%
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Spain vs Portugal                   | Spain           | 55.31%
#
# ========================================
# Knockout ROUND
# ========================================
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Argentina vs Colombia               | Colombia        | 35.48%
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# United States vs Morocco            | United States   | 27.92%
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Mexico vs Belgium                   | Belgium         | 19.46%
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Spain vs England                    | England         | 39.67%
#
# ========================================
# Knockout ROUND
# ========================================
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# England vs United States            | England         | 56.27%
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Belgium vs Colombia                 | Belgium         | 40.88%
#
# ========================================
# Knockout ROUND
# ========================================
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# England vs Belgium                  | Belgium         | 41.70%
#
# ========================================
# Knockout ROUND
# ========================================
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Argentina vs Brazil                 | Brazil          | 38.94%
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# United States vs Mexico             | Mexico          | 45.13%
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Morocco vs France                   | Morocco         | 38.15%
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Portugal vs Netherlands             | Portugal        | 32.71%
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Belgium vs Colombia                 | Colombia        | 40.88%
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Germany vs Uruguay                  | Uruguay         | 39.40%
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Croatia vs England                  | England         | 29.71%
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Italy vs Spain                      | Spain           | 30.11%
#
# ========================================
# Knockout ROUND
# ========================================
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Spain vs Portugal                   | Portugal        | 55.31%
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Colombia vs England                 | Colombia        | 30.17%
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Morocco vs Uruguay                  | Uruguay         | 43.61%
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Brazil vs Mexico                    | Brazil          | 52.46%
#
# ========================================
# Knockout ROUND
# ========================================
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Portugal vs Colombia                | Colombia        | 30.53%
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Brazil vs Uruguay                   | Uruguay         | 40.20%
#
# ========================================
# Knockout ROUND
# ========================================
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Uruguay vs Colombia                 | Uruguay         | 31.44%
#
# ========================================
# Knockout ROUND
# ========================================
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Spain vs United States              | United States   | 58.60%
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Croatia vs Colombia                 | Colombia        | 36.90%
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Belgium vs Mexico                   | Mexico          | 59.67%
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Netherlands vs Morocco              | Morocco         | 35.27%
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Portugal vs France                  | France          | 31.37%
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Uruguay vs Brazil                   | Brazil          | 34.72%
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Italy vs England                    | England         | 32.15%
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Germany vs Argentina                | Argentina       | 35.15%
#
# ========================================
# Knockout ROUND
# ========================================
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# England vs Brazil                   | Brazil          | 48.96%
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Mexico vs United States             | United States   | 30.29%
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# France vs Morocco                   | Morocco         | 36.69%
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Argentina vs Colombia               | Colombia        | 35.48%
#
# ========================================
# Knockout ROUND
# ========================================
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# Brazil vs Morocco                   | Brazil          | 34.20%
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# United States vs Colombia           | United States   | 27.76%
#
# ========================================
# Knockout ROUND
# ========================================
# MATCHUP                             | WINNER          | WIN PROB
# -----------------------------------------------------------------
# United States vs Brazil             | Brazil          | 30.83%

# %%
print(winners_list)
# Out:
# ['England', 'France', 'Croatia', 'Portugal', 'Spain', 'Belgium', 'Netherlands', 'Germany', 'Belgium', 'Morocco', 'France', 'Germany', 'France', 'England', 'Italy', 'France', 'Spain', 'Belgium', 'England', 'Italy', 'Spain', 'Belgium', 'Belgium', 'Belgium', 'Brazil', 'England', 'Argentina', 'Spain', 'Croatia', 'Morocco', 'Portugal', 'Spain', 'Italy', 'Portugal', 'England', 'Italy', 'England', 'Italy', 'Italy', 'Morocco', 'Morocco', 'Brazil', 'Italy', 'England', 'Colombia', 'United States', 'Italy', 'England', 'Belgium', 'Portugal', 'France', 'Belgium', 'Croatia', 'Argentina', 'Spain', 'Morocco', 'Italy', 'Uruguay', 'Belgium', 'Spain', 'Argentina', 'Belgium', 'England', 'Argentina', 'France', 'Uruguay', 'United States', 'France', 'Belgium', 'Mexico', 'Spain', 'Argentina', 'England', 'Colombia', 'Italy', 'England', 'Netherlands', 'Belgium', 'Portugal', 'Morocco', 'Italy', 'France', 'England', 'Spain', 'Mexico', 'Italy', 'Spain', 'Brazil', 'Portugal', 'Spain', 'Italy', 'Morocco', 'England', 'Italy', 'Netherlands', 'France', 'Germany', 'England', 'France', 'Spain', 'France', 'Morocco', 'Spain', 'Spain', 'Belgium', 'Belgium', 'Croatia', 'Spain', 'Brazil', 'Netherlands', 'Morocco', 'Germany', 'Croatia', 'Brazil', 'Croatia', 'Netherlands', 'Uruguay', 'Colombia', 'Argentina', 'Croatia', 'Croatia', 'Brazil', 'Morocco', 'Germany', 'Germany', 'Croatia', 'Croatia', 'Colombia', 'France', 'Germany', 'France', 'Croatia', 'Uruguay', 'Colombia', 'Colombia', 'Spain', 'England', 'United States', 'England', 'Croatia', 'Spain', 'England', 'Netherlands', 'Morocco', 'Belgium', 'France', 'Brazil', 'Colombia', 'Spain', 'Morocco', 'Uruguay', 'Argentina', 'Germany', 'Netherlands', 'Spain', 'England', 'Netherlands', 'Morocco', 'Brazil', 'Portugal', 'England', 'Croatia', 'Colombia', 'England', 'Italy', 'Italy', 'Germany', 'England', 'Argentina', 'France', 'Germany', 'United States', 'Spain', 'Colombia', 'Belgium', 'Colombia', 'Belgium', 'Italy', 'Mexico', 'Croatia', 'Brazil', 'Netherlands', 'Brazil', 'Croatia', 'England', 'Portugal', 'Netherlands', 'England', 'Uruguay', 'Croatia', 'England', 'Belgium', 'Germany', 'Spain', 'Colombia', 'Belgium', 'Mexico', 'Colombia', 'Belgium', 'France', 'Germany', 'Uruguay', 'Uruguay', 'Spain', 'Croatia', 'Argentina', 'England', 'Italy', 'England', 'Colombia', 'Italy', 'England', 'Colombia', 'Italy', 'France', 'Germany', 'Argentina', 'England', 'Croatia', 'France', 'Morocco', 'Argentina', 'Brazil', 'United States', 'Spain', 'Croatia', 'Belgium', 'Germany', 'Colombia', 'England', 'United States', 'Spain', 'Netherlands', 'Spain', 'Belgium', 'United States', 'Colombia', 'Italy', 'Spain', 'Portugal', 'Belgium', 'Spain', 'Colombia', 'Belgium', 'Spain', 'Brazil', 'Germany', 'Spain', 'Netherlands', 'Spain', 'Morocco', 'Italy', 'Belgium', 'Argentina', 'Spain', 'Uruguay', 'Spain', 'Colombia', 'England', 'Netherlands', 'England', 'Argentina', 'Spain', 'Argentina', 'Colombia', 'Brazil', 'England', 'Brazil', 'Colombia', 'Spain', 'Spain', 'Belgium', 'Argentina', 'Uruguay', 'Brazil', 'Morocco', 'Spain', 'Germany', 'Morocco', 'England', 'Italy', 'Morocco', 'Italy', 'United States', 'Morocco', 'Spain', 'Morocco', 'Brazil', 'Argentina', 'Spain', 'England', 'Morocco', 'France', 'Netherlands', 'Spain', 'France', 'Belgium', 'England', 'Netherlands', 'England', 'Argentina', 'England', 'Croatia', 'England', 'Spain', 'Croatia', 'Belgium', 'France', 'Spain', 'France', 'England', 'Italy', 'Spain', 'Spain', 'England', 'Spain', 'Italy', 'Colombia', 'Argentina', 'England', 'Colombia', 'England', 'England', 'France', 'Spain', 'Brazil', 'Spain', 'Brazil', 'Spain', 'Germany', 'Argentina', 'Italy', 'Italy', 'England', 'Argentina', 'Belgium', 'Belgium', 'Germany', 'England', 'Mexico', 'Spain', 'Belgium', 'England', 'Netherlands', 'Croatia', 'Portugal', 'Spain', 'Belgium', 'Netherlands', 'Argentina', 'Brazil', 'Argentina', 'Netherlands', 'Morocco', 'Argentina', 'Uruguay', 'Uruguay', 'France', 'England', 'Morocco', 'Argentina', 'England', 'Croatia', 'England ...

# %%
count = Counter(winners_list)
print(count)
# Out:
# Counter({'Spain': 1333, 'England': 1202, 'Belgium': 875, 'Italy': 785, 'Colombia': 698, 'Morocco': 694, 'France': 637, 'Croatia': 613, 'Argentina': 567, 'Netherlands': 553, 'Brazil': 516, 'Germany': 466, 'Portugal': 344, 'Uruguay': 340, 'United States': 264, 'Mexico': 113})
